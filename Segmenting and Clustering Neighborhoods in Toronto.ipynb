# %% [markdown]
# ## Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# #### *All 3 questions are saved under the same ipynb file

# %% [markdown]
# #### 1. To create a dataframe will consist of three columns: PostalCode, Borough, and Neighborhood. following the instructions.

# %%
#install lxml to scrape the table
# !pip install lxml    
import pandas as pd
# Out:
# Requirement already satisfied: lxml in c:\users\leonardo\anaconda3\lib\site-packages (4.5.0)

# %%
#read the html webpage, scrape the tables on the webpage into a list file, check the length of the file.
raw=pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
len(raw)
# Out:
# 3

# %%
#show the table we need as part of the list file
raw[0]
# Out:
#     Postal code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                                  NaN
# 1                                                  NaN
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# ..                                                 ...
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178  Mimico NW / The Queensway West / South of Bloo...
# 179                                                NaN
#
# [180 rows x 3 columns]

# %%
#looks like we need to flatten the complicated list into a simple list, then make into a dataframe
df=pd.DataFrame(raw[0])
df.rename(columns={'Postal code': 'PostalCode'}, inplace=True)
df.head(10)
# Out:
#   PostalCode           Borough                                  Neighborhood
# 0        M1A      Not assigned                                           NaN
# 1        M2A      Not assigned                                           NaN
# 2        M3A        North York                                     Parkwoods
# 3        M4A        North York                              Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park / Harbourfront
# 5        M6A        North York             Lawrence Manor / Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government
# 7        M8A      Not assigned                                           NaN
# 8        M9A         Etobicoke                              Islington Avenue
# 9        M1B       Scarborough                               Malvern / Rouge

# %%
#clean up the data, drop the row with Borough Not assigned, change the format in the Neighborhood column
df=df[df['Borough']!='Not assigned']
df['Neighborhood']=df['Neighborhood'].str.replace(' / ',',')
df.head(10)
# Out:
#    PostalCode           Borough                                Neighborhood
# 2         M3A        North York                                   Parkwoods
# 3         M4A        North York                            Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park,Harbourfront
# 5         M6A        North York             Lawrence Manor,Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park,Ontario Provincial Government
# 8         M9A         Etobicoke                            Islington Avenue
# 9         M1B       Scarborough                               Malvern,Rouge
# 11        M3B        North York                                   Don Mills
# 12        M4B         East York              Parkview Hill,Woodbine Gardens
# 13        M5B  Downtown Toronto                    Garden District, Ryerson

# %% [markdown]
# #check to see if any Borough has Neighborhood 'Not assigned'.
# df['Neighborhood'].str.contains('Not').sum()

# %%
#reset index
df.reset_index(drop=True,inplace=True)
df.head()
# Out:
#   PostalCode           Borough                                Neighborhood
# 0        M3A        North York                                   Parkwoods
# 1        M4A        North York                            Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park,Harbourfront
# 3        M6A        North York             Lawrence Manor,Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park,Ontario Provincial Government

# %%
#check the volume of the data frame
df.shape
# Out:
# (103, 3)

# %% [markdown]
# #### 2. Get the latitude and the longitude coordinates of each neighborhood and add to the dataframe

# %%
# !pip install geocoder
# Out:
# Requirement already satisfied: geocoder in c:\users\leonardo\anaconda3\lib\site-packages (1.38.1)
# Requirement already satisfied: ratelim in c:\users\leonardo\anaconda3\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in c:\users\leonardo\anaconda3\lib\site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: click in c:\users\leonardo\anaconda3\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: future in c:\users\leonardo\anaconda3\lib\site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: six in c:\users\leonardo\anaconda3\lib\site-packages (from geocoder) (1.14.0)
# Requirement already satisfied: decorator in c:\users\leonardo\anaconda3\lib\site-packages (from ratelim->geocoder) (4.4.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\leonardo\anaconda3\lib\site-packages (from requests->geocoder) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\leonardo\anaconda3\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\leonardo\anaconda3\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\leonardo\anaconda3\lib\site-packages (from requests->geocoder) (2019.11.28)

# %%
#find the Latitude Longitude based on the postal code (using geocoder and arcgis)
import geocoder
def get_geocoder(postal_code):
     # initialize your variable to None
     lat_lng_coords = None
     # loop until you get the coordinates
     while(lat_lng_coords is None):
       g = geocoder.arcgis('{}, Toronto, Ontario'.format(postal_code))
       lat_lng_coords = g.latlng
     latitude = lat_lng_coords[0]
     longitude = lat_lng_coords[1]
     return latitude,longitude

# %%
#write into a list (most efficient way I have tried)then convert into a proper dataframe)
latlng_list=[]
for i in df['PostalCode'].values:
    m=list(get_geocoder(i))
    m.append(i)
    latlng_list.append(m)
df1=pd.DataFrame(latlng_list,columns=['latitude','longitude','PostalCode'])
df1.head()
# Out:
#     latitude  longitude PostalCode
# 0  43.752935 -79.335641        M3A
# 1  43.728102 -79.311890        M4A
# 2  43.650964 -79.353041        M5A
# 3  43.723265 -79.451211        M6A
# 4  43.661790 -79.389390        M7A

# %%
#Merge the dataframe together.
df_final=pd.merge(df,df1,on='PostalCode')

# %%
df_final.head()
# Out:
#   PostalCode           Borough                                Neighborhood  \
# 0        M3A        North York                                   Parkwoods
# 1        M4A        North York                            Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park,Harbourfront
# 3        M6A        North York             Lawrence Manor,Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park,Ontario Provincial Government
#
#     latitude  longitude
# 0  43.752935 -79.335641
# 1  43.728102 -79.311890
# 2  43.650964 -79.353041
# 3  43.723265 -79.451211
# 4  43.661790 -79.389390

# %% [markdown]
# #### 3. Explore and cluster the neighborhoods in Toronto.

# %%
#import libraries that are needed
import numpy as np 
import json 

# !pip install geopy
from geopy.geocoders import Nominatim

import requests
from pandas.io.json import json_normalize

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium 
print('Libraries imported.')

# %%
#find Geo coordinate of city of Toronto!
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="T_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of City of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of City of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# now we can sort the data further to find the Borough that contains toronto and make it into a new dataframe toronto_center

# %%
toronto_center=df_final[df_final['Borough'].str.contains("Toronto")].reset_index(drop=True)
toronto_center.head()
# Out:
#   PostalCode           Borough                                Neighborhood  \
# 0        M5A  Downtown Toronto                    Regent Park,Harbourfront
# 1        M7A  Downtown Toronto  Queen's Park,Ontario Provincial Government
# 2        M5B  Downtown Toronto                    Garden District, Ryerson
# 3        M5C  Downtown Toronto                              St. James Town
# 4        M4E      East Toronto                                 The Beaches
#
#     latitude  longitude
# 0  43.650964 -79.353041
# 1  43.661790 -79.389390
# 2  43.657491 -79.377529
# 3  43.651734 -79.375554
# 4  43.678148 -79.295349

# %% [markdown]
# create map to visualize these neigborhoods on the map

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=12)
# add markers to map from the previous generated data frame
for lat, lng, borough, neighborhood in zip(toronto_center['latitude'], toronto_center['longitude'], toronto_center['Borough'], toronto_center['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='Orange',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Use Foursquare api now, we can define the credential and version use some varibles

# %%
CLIENT_ID = '3SXSKUTJPZQZUQCLQ440ESICM4VZ5AGZMQIBDF45FAJVQ2ZB'
CLIENT_SECRET = 'VY3EAI11XCAHOSDW2EMZPKP0A1VDDOP103IHJWNQOBEQ23K0'
VERSION = '20180605'

# %% [markdown]
# create a function to explore the venues in each neighborhood inte toronto_center data frame

# %%
def getNearbyVenues(names, latitudes, longitudes):
    radius=500
    LIMIT=200
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Run this function with the dataframe toronto_center

# %%
toronto_venues = getNearbyVenues(names=toronto_center['Neighborhood'],latitudes=toronto_center['latitude'],longitudes=toronto_center['longitude'])
# Out:
# Regent Park,Harbourfront
# Queen's Park,Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond,Adelaide,King
# Dufferin,Dovercourt Village
# Harbourfront East,Union Station,Toronto Islands
# Little Portugal,Trinity
# The Danforth West,Riverdale
# Toronto Dominion Centre,Design Exchange
# Brockton,Parkdale Village,Exhibition Place
# India Bazaar,The Beaches West
# Commerce Court,Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West
# High Park,The Junction South
# North Toronto West
# The Annex,North Midtown,Yorkville
# Parkdale,Roncesvalles
# Davisville
# University of Toronto,Harbord
# Runnymede,Swansea
# Moore Park,Summerhill East
# Kensington Market,Chinatown,Grange Park
# Summerhill West,Rathnelly,South Hill,Forest Hill SE,Deer Park
# CN Tower,King and Spadina,Railway Lands,Harbourfront West,Bathurst  Quay,South Niagara,Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town,Cabbagetown
# First Canadian Place,Underground city
# Church and Wellesley
# Business reply mail Processing CentrE

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (1675, 7)
#                Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park,Harbourfront              43.650964              -79.353041
# 1  Regent Park,Harbourfront              43.650964              -79.353041
# 2  Regent Park,Harbourfront              43.650964              -79.353041
# 3  Regent Park,Harbourfront              43.650964              -79.353041
# 4  Regent Park,Harbourfront              43.650964              -79.353041
#
#                                   Venue  Venue Latitude  Venue Longitude  \
# 0                           Souk Tabule       43.653756       -79.354390
# 1  Young Centre for the Performing Arts       43.650825       -79.357593
# 2                   SOMA chocolatemaker       43.650622       -79.358127
# 3            Cluny Bistro & Boulangerie       43.650565       -79.357843
# 4                           BATLgrounds       43.647088       -79.351306
#
#              Venue Category
# 0  Mediterranean Restaurant
# 1     Performing Arts Venue
# 2            Chocolate Shop
# 3         French Restaurant
# 4        Athletics & Sports

# %% [markdown]
# now let's take a look at how many venues in each neighborhood

# %%
toronto_venues[['Neighborhood','Venue']].groupby('Neighborhood').count()
# Out:
#                                                     Venue
# Neighborhood
# Berczy Park                                            66
# Brockton,Parkdale Village,Exhibition Place             45
# Business reply mail Processing CentrE                 100
# CN Tower,King and Spadina,Railway Lands,Harbour...     67
# Central Bay Street                                     79
# Christie                                               11
# Church and Wellesley                                   86
# Commerce Court,Victoria Hotel                         100
# Davisville                                             28
# Davisville North                                        4
# Dufferin,Dovercourt Village                            15
# First Canadian Place,Underground city                 100
# Forest Hill North & West                                1
# Garden District, Ryerson                              100
# Harbourfront East,Union Station,Toronto Islands         8
# High Park,The Junction South                            4
# India Bazaar,The Beaches West                          18
# Kensington Market,Chinatown,Grange Park                62
# Lawrence Park                                           2
# Little Portugal,Trinity                                52
# Moore Park,Summerhill East                              3
# North Toronto West                                      4
# Parkdale,Roncesvalles                                  67
# Queen's Park,Ontario Provincial Government             37
# Regent Park,Harbourfront                               27
# Richmond,Adelaide,King                                100
# Rosedale                                                4
# Roselawn                                                1
# Runnymede,Swansea                                      51
# St. James Town                                        100
# St. James Town,Cabbagetown                             49
# Stn A PO Boxes                                        100
# Studio District                                         4
# Summerhill West,Rathnelly,South Hill,Forest Hil...     10
# The Annex,North Midtown,Yorkville                      26
# The Beaches                                             5
# The Danforth West,Riverdale                             5
# Toronto Dominion Centre,Design Exchange               100
# University of Toronto,Harbord                          34

# %%
#how many unique categories do we have here for the venues?
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 226 uniques categories.

# %% [markdown]
# analyse each neighberhood with one hot ecoding

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood']

# %%
toronto_onehot.shape
# Out:
# (1675, 226)

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.head()
# Out:
#                                         Neighborhood  Accessories Store  \
# 0                                        Berczy Park           0.000000
# 1         Brockton,Parkdale Village,Exhibition Place           0.022222
# 2              Business reply mail Processing CentrE           0.000000
# 3  CN Tower,King and Spadina,Railway Lands,Harbou...           0.000000
# 4                                 Central Bay Street           0.000000
#
#    Afghan Restaurant  American Restaurant  Art Gallery  Art Museum  \
# 0                0.0             0.000000     0.015152    0.000000
# 1                0.0             0.000000     0.022222    0.000000
# 2                0.0             0.030000     0.010000    0.000000
# 3                0.0             0.000000     0.000000    0.000000
# 4                0.0             0.012658     0.000000    0.012658
#
#    Arts & Crafts Store  Asian Restaurant  Athletics & Sports  Auto Workshop  \
# 0             0.000000          0.000000                 0.0            0.0
# 1             0.022222          0.000000                 0.0            0.0
# 2             0.010000          0.030000                 0.0            0.0
# 3             0.000000          0.014925                 0.0            0.0
# 4             0.000000          0.000000                 0.0            0.0
#
#    ...     Trail  Train Station  Transportation Service  \
# 0  ...  0.000000            0.0                     0.0
# 1  ...  0.000000            0.0                     0.0
# 2  ...  0.000000            0.0                     0.0
# 3  ...  0.014925            0.0                     0.0
# 4  ...  0.000000            0.0                     0.0
#
#    Vegetarian / Vegan Restaurant  Video Game Store  Vietnamese Restaurant  \
# 0                       0.015152          0.000000               0.000000
# 1                       0.000000          0.000000               0.000000
# 2                       0.020000          0.000000               0.000000
# 3                       0.000000          0.000000               0.000000
# 4                       0.000000          0.012658               0.012658
#
#    Wine Bar  Wings Joint  Women's Store  Yoga Studio
# 0  0.000000          0.0            0.0          0.0
# 1  0.000000          0.0            0.0          0.0
# 2  0.010000          0.0            0.0          0.0
# 3  0.000000          0.0            0.0          0.0
# 4  0.012658          0.0            0.0          0.0
#
# [5 rows x 226 columns]

# %% [markdown]
# Let's print each neighborhood along with the top 5 most common venues

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp =  toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

# %%
].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Berczy Park----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1          Restaurant  0.05
# 2        Cocktail Bar  0.05
# 3  Seafood Restaurant  0.05
# 4         Cheese Shop  0.03
#
#
# ----Brockton,Parkdale Village,Exhibition Place----
#                     venue  freq
# 0             Coffee Shop  0.09
# 1                    Café  0.07
# 2              Restaurant  0.04
# 3  Thrift / Vintage Store  0.04
# 4               Gift Shop  0.04
#
#
# ----Business reply mail Processing CentrE----
#               venue  freq
# 0       Coffee Shop  0.09
# 1        Restaurant  0.04
# 2               Bar  0.04
# 3             Hotel  0.04
# 4  Asian Restaurant  0.03
#
#
# ----CN Tower,King and Spadina,Railway Lands,Harbourfront West,Bathurst  Quay,South Niagara,Island airport----
#                venue  freq
# 0        Coffee Shop  0.07
# 1         Restaurant  0.06
# 2               Café  0.06
# 3  French Restaurant  0.04
# 4               Park  0.04
#
#
# ----Central Bay Street----
#                        venue  freq
# 0                Coffee Shop  0.14
# 1             Clothing Store  0.06
# 2        Japanese Restaurant  0.04
# 3  Middle Eastern Restaurant  0.04
# 4       Fast Food Restaurant  0.03
#
#
# ----Christie----
#            venue  freq
# 0           Café  0.27
# 1  Grocery Store  0.27
# 2    Coffee Shop  0.09
# 3     Baby Store  0.09
# 4           Park  0.09
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1  Japanese Restaurant  0.06
# 2           Restaurant  0.05
# 3              Gay Bar  0.05
# 4                 Café  0.03
#
#
# ----Commerce Court,Victoria Hotel----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                 Café  0.06
# 2           Restaurant  0.06
# 3                Hotel  0.05
# 4  American Restaurant  0.04
#
#
# ----Davisville----
#                 venue  freq
# 0        Dessert Shop  0.11
# 1     Thai Restaurant  0.07
# 2                Café  0.07
# 3      Sandwich Place  0.07
# 4  Italian Restaurant  0.07
#
#
# ----Davisville North----
#                venue  freq
# 0     Breakfast Spot  0.25
# 1   Department Store  0.25
# 2  Food & Drink Shop  0.25
# 3               Park  0.25
# 4  Accessories Store  0.00
#
#
# ----Dufferin,Dovercourt Village----
#            venue  freq
# 0  Grocery Store  0.13
# 1           Park  0.13
# 2         Bakery  0.07
# 3       Bus Line  0.07
# 4     Smoke Shop  0.07
#
#
# ----First Canadian Place,Underground city----
#                  venue  freq
# 0          Coffee Shop  0.14
# 1                 Café  0.07
# 2           Restaurant  0.06
# 3                Hotel  0.04
# 4  American Restaurant  0.04
#
#
# ----Forest Hill North & West----
#                         venue  freq
# 0                        Park   1.0
# 1           Accessories Store   0.0
# 2                Noodle House   0.0
# 3          Miscellaneous Shop   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----Garden District, Ryerson----
#                        venue  freq
# 0                Coffee Shop  0.11
# 1             Clothing Store  0.07
# 2             Sandwich Place  0.04
# 3  Middle Eastern Restaurant  0.04
# 4                       Café  0.03
#
#
# ----Harbourfront East,Union Station,Toronto Islands----
#                   venue  freq
# 0       Harbor / Marina  0.38
# 1            Theme Park  0.25
# 2                  Park  0.12
# 3  Fast Food Restaurant  0.12
# 4                  Farm  0.12
#
#
# ----High Park,The Junction South----
#                   venue  freq
# 0     Convenience Store  0.25
# 1                  Park  0.25
# 2  Gym / Fitness Center  0.25
# 3           Gas Station  0.25
# 4     Accessories Store  0.00
#
#
# ----India Bazaar,The Beaches West----
#           venue  freq
# 0          Park  0.11
# 1    Steakhouse  0.06
# 2  Liquor Store  0.06
# 3           Pub  0.06
# 4    Restaurant  0.06
#
#
# ----Kensington Market,Chinatown,Grange Park----
#                    venue  freq
# 0                   Café  0.06
# 1     Mexican Restaurant  0.05
# 2    Dumpling Restaurant  0.05
# 3  Vietnamese Restaurant  0.05
# 4            Coffee Shop  0.05
#
#
# ----Lawrence Park----
#                 venue  freq
# 0            Bus Line   0.5
# 1         Swim School   0.5
# 2   Accessories Store   0.0
# 3           Nightclub   0.0
# 4  Miscellaneous Shop   0.0
#
#
# ----Little Portugal,Trinity----
#               venue  freq
# 0               Bar  0.08
# 1       Coffee Shop  0.08
# 2        Restaurant  0.06
# 3      Cocktail Bar  0.06
# 4  Asian Restaurant  0.04
#
#
# ----Moore Park,Summerhill East----
#                         venue  freq
# 0                  Playground  0.33
# 1           Convenience Store  0.33
# 2                         Gym  0.33
# 3     North Indian Restaurant  0.00
# 4  Modern European Restaurant  0.00
#
#
# ----North Toronto West----
#         venue  freq
# 0  Playground  0.25
# 1        Park  0.25
# 2    Gym Pool  0.25
# 3      Garden  0.25
# 4   Nightclub  0.00
#
#
# ----Parkdale,Roncesvalles----
#                          venue  freq
# 0                  Coffee Shop  0.09
# 1             Sushi Restaurant  0.04
# 2  Eastern European Restaurant  0.04
# 3              Thai Restaurant  0.04
# 4                   Restaurant  0.04
#
#
# ----Queen's Park,Ontario Provincial Government----
#                  venue  freq
# 0          Coffee Shop  0.32
# 1                 Café  0.05
# 2           Hobby Shop  0.03
# 3  Fried Chicken Joint  0.03
# 4        Burrito Place  0.03
#
#
# ----Regent Park,Harbourfront----
#                 venue  freq
# 0                 Pub  0.11
# 1         Coffee Shop  0.11
# 2                Café  0.07
# 3         Music Venue  0.07
# 4  Athletics & Sports  0.07
#
#
# ----Richmond,Adelaide,King----
#          venue  freq
# 0  Coffee Shop  0.09
# 1   Restaurant  0.06
# 2         Café  0.06
# 3          Gym  0.04
# 4       Bakery  0.03
#
#
# ----Rosedale----
#            venue  freq
# 0     Playground  0.25
# 1           Park  0.25
# 2    Candy Store  0.25
# 3  Grocery Store  0.25
# 4   Noodle House  0.00
#
#
# ----Roselawn----
#                              venue  freq
# 0                      IT Services   1.0
# 1                Accessories Store   0.0
# 2          North Indian Restaurant   0.0
# 3       Modern European Restaurant   0.0
# 4  Molecular Gastronomy Restaurant   0.0
#
#
# ----Runnymede,Swansea----
#                 venue  freq
# 0                Café  0.10
# 1    Sushi Restaurant  0.06
# 2         Pizza Place  0.06
# 3  Falafel Restaurant  0.04
# 4                 Pub  0.04
#
#
# ----St. James Town----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1                Café  0.05
# 2        Cocktail Bar  0.04
# 3  Italian Restaurant  0.04
# 4          Restaurant  0.04
#
#
# ----St. James Town,Cabbagetown----
#                venue  freq
# 0               Café  0.06
# 1        Pizza Place  0.06
# 2        Coffee Shop  0.06
# 3  Convenience Store  0.04
# 4         Restaurant  0.04
#
#
# ----Stn A PO Boxes----
#               venue  freq
# 0       Coffee Shop  0.09
# 1        Restaurant  0.04
# 2               Bar  0.04
# 3             Hotel  0.04
# 4  Asian Restaurant  0.03
#
#
# ----Studio District----
#                      venue  freq
# 0           Baseball Field  0.25
# 1         Business Service  0.25
# 2             Night Market  0.25
# 3      Government Building  0.25
# 4  North Indian Restaurant  0.00
#
#
# ----Summerhill West,Rathnelly,South Hill,Forest Hill SE,Deer Park----
#                 venue  freq
# 0  Light Rail Station   0.2
# 1         Coffee Shop   0.2
# 2  Athletics & Sports   0.2
# 3        Skating Rink   0.1
# 4         Supermarket   0.1
#
#
# ----The Annex,North Midtown,Yorkville----
#                         venue  freq
# 0              Sandwich Place  0.12
# 1                        Café  0.08
# 2  Modern European Restaurant  0.04
# 3                Liquor Store  0.04
# 4                  Donut Shop  0.04
#
#
# ----The Beaches----
#                venue  freq
# 0             Church   0.2
# 1  Health Food Store   0.2
# 2                Pub   0.2
# 3              Trail   0.2
# 4  Accessories Store   0.0
#
#
# ----The Danforth West,Riverdale----
#               venue  freq
# 0          Bus Line   0.2
# 1  Business Service   0.2
# 2    Discount Store   0.2
# 3              Park   0.2
# 4     Grocery Store   0.2
#
#
# ----Toronto Dominion Centre,Design Exchange----
#          venue  freq
# 0  Coffee Shop  0.13
# 1        Hotel  0.08
# 2         Café  0.07
# 3   Restaurant  0.05
# 4    Gastropub  0.03
#
#
# ----University of Toronto,Harbord----
#                  venue  freq
# 0                 Café  0.15
# 1           Restaurant  0.06
# 2   Italian Restaurant  0.06
# 3  Japanese Restaurant  0.06
# 4            Bookstore  0.06

# %% [markdown]
# Let's print each neighborhood along with the top 5 most common venues, then write the top 10 venues into a dataframe

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10
indicators = ['st', 'nd', 'rd']
# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park           Coffee Shop
# 1         Brockton,Parkdale Village,Exhibition Place           Coffee Shop
# 2              Business reply mail Processing CentrE           Coffee Shop
# 3  CN Tower,King and Spadina,Railway Lands,Harbou...           Coffee Shop
# 4                                 Central Bay Street           Coffee Shop
#
#   2nd Most Common Venue      3rd Most Common Venue 4th Most Common Venue  \
# 0          Cocktail Bar                 Restaurant    Seafood Restaurant
# 1                  Café                 Restaurant             Gift Shop
# 2                   Bar                 Restaurant                 Hotel
# 3                  Café                 Restaurant     French Restaurant
# 4        Clothing Store  Middle Eastern Restaurant   Japanese Restaurant
#
#   5th Most Common Venue   6th Most Common Venue 7th Most Common Venue  \
# 0        Farmers Market          Breakfast Spot           Cheese Shop
# 1           Pizza Place  Thrift / Vintage Store     French Restaurant
# 2   American Restaurant        Asian Restaurant    Italian Restaurant
# 3                  Park                     Bar  Gym / Fitness Center
# 4        Breakfast Spot         Bubble Tea Shop        Sandwich Place
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                  Café              Beer Bar                  Hotel
# 1             Pet Store    Mexican Restaurant               Boutique
# 2                   Gym            Taco Place    Japanese Restaurant
# 3    Italian Restaurant                Lounge              Speakeasy
# 4  Fast Food Restaurant    Italian Restaurant             Restaurant

# %% [markdown]
# Cluster Neighborhoods : let's Run k-means to cluster the neighborhood into 3 clusters.

# %%
# set number of clusters
kclusters = 4

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:25]
# Out:
# array([0, 0, 0, 0, 0, 2, 0, 0, 0, 0, 2, 0, 3, 0, 0, 2, 0, 0, 2, 0, 0, 0,
#        0, 0, 0])

# %%
neighborhoods_venues_sorted=neighborhoods_venues_sorted.drop('Cluster Labels',1)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
toronto_merge = toronto_center

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merge = toronto_merge.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

# %%
#check if the last column contains the cluster labels
toronto_merge.columns
# Out:
# Index(['PostalCode', 'Borough', 'Neighborhood', 'latitude', 'longitude',
#        'Cluster Labels', '1st Most Common Venue', '2nd Most Common Venue',
#        '3rd Most Common Venue', '4th Most Common Venue',
#        '5th Most Common Venue', '6th Most Common Venue',
#        '7th Most Common Venue', '8th Most Common Venue',
#        '9th Most Common Venue', '10th Most Common Venue'],
#       dtype='object')

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merge['latitude'], toronto_merge['longitude'], toronto_merge['Neighborhood'], toronto_merge['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# upon observation, cluster1 (cluster label 0 neighberhood represent the more downtown core neighborhood type)

# %%
toronto_merge.loc[toronto_merge['Cluster Labels'] == 0, toronto_merge.columns[[1] + list(range(5, toronto_merge.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 0   Downtown Toronto               0           Coffee Shop
# 1   Downtown Toronto               0           Coffee Shop
# 2   Downtown Toronto               0           Coffee Shop
# 3   Downtown Toronto               0           Coffee Shop
# 4       East Toronto               0     Health Food Store
# 5   Downtown Toronto               0           Coffee Shop
# 6   Downtown Toronto               0           Coffee Shop
# 8   Downtown Toronto               0           Coffee Shop
# 10  Downtown Toronto               0       Harbor / Marina
# 11      West Toronto               0           Coffee Shop
# 13  Downtown Toronto               0           Coffee Shop
# 14      West Toronto               0           Coffee Shop
# 15      East Toronto               0                  Park
# 16  Downtown Toronto               0           Coffee Shop
# 17      East Toronto               0          Night Market
# 20   Central Toronto               0     Food & Drink Shop
# 23   Central Toronto               0            Playground
# 24   Central Toronto               0        Sandwich Place
# 25      West Toronto               0           Coffee Shop
# 26   Central Toronto               0          Dessert Shop
# 27  Downtown Toronto               0                  Café
# 28      West Toronto               0                  Café
# 29   Central Toronto               0     Convenience Store
# 30  Downtown Toronto               0                  Café
# 31   Central Toronto               0    Athletics & Sports
# 32  Downtown Toronto               0           Coffee Shop
# 34  Downtown Toronto               0           Coffee Shop
# 35  Downtown Toronto               0                  Café
# 36  Downtown Toronto               0           Coffee Shop
# 37  Downtown Toronto               0           Coffee Shop
# 38      East Toronto               0           Coffee Shop
#
#    2nd Most Common Venue        3rd Most Common Venue  \
# 0                    Pub                         Café
# 1                   Café                  Yoga Studio
# 2         Clothing Store               Sandwich Place
# 3                   Café                   Restaurant
# 4                    Pub                        Trail
# 5           Cocktail Bar                   Restaurant
# 6         Clothing Store    Middle Eastern Restaurant
# 8                   Café                   Restaurant
# 10            Theme Park         Fast Food Restaurant
# 11                   Bar                   Restaurant
# 13                 Hotel                         Café
# 14                  Café                   Restaurant
# 15             Pet Store                   Board Shop
# 16            Restaurant                         Café
# 17      Business Service          Government Building
# 20        Breakfast Spot                         Park
# 23              Gym Pool                         Park
# 24                  Café            Indian Restaurant
# 25                Bakery  Eastern European Restaurant
# 26                  Café               Sandwich Place
# 27                  Park                   Restaurant
# 28           Pizza Place             Sushi Restaurant
# 29            Playground                          Gym
# 30           Coffee Shop           Mexican Restaurant
# 31           Coffee Shop           Light Rail Station
# 32                  Café                   Restaurant
# 34                   Bar                   Restaurant
# 35           Coffee Shop                  Pizza Place
# 36                  Café                   Restaurant
# 37   Japanese Restaurant                   Restaurant
# 38                   Bar                   Restaurant
#
#         4th Most Common Venue          5th Most Common Venue  \
# 0          Athletics & Sports                    Music Venue
# 1                       Diner                           Park
# 2   Middle Eastern Restaurant                          Hotel
# 3          Italian Restaurant                   Cocktail Bar
# 4                      Church                   Cupcake Shop
# 5          Seafood Restaurant                 Farmers Market
# 6         Japanese Restaurant                 Breakfast Spot
# 8                         Gym                Thai Restaurant
# 10                       Park                           Farm
# 11               Cocktail Bar                       Wine Bar
# 13                 Restaurant            American Restaurant
# 14                  Gift Shop                    Pizza Place
# 15             Ice Cream Shop                   Intersection
# 16                      Hotel            American Restaurant
# 17             Baseball Field                    Yoga Studio
# 20           Department Store              Electronics Store
# 23                     Garden                    Yoga Studio
# 24         Mexican Restaurant      Middle Eastern Restaurant
# 25                 Restaurant               Sushi Restaurant
# 26         Italian Restaurant                Thai Restaurant
# 27                  Bookstore            Japanese Restaurant
# 28         Italian Restaurant                          Diner
# 29        Dumpling Restaurant                    Flower Shop
# 30      Vietnamese Restaurant  Vegetarian / Vegan Restaurant
# 31                       Park                   Skating Rink
# 32          French Restaurant                           Park
# 34                      Hotel            American Restaurant
# 35                   Pharmacy                         Bakery
# 36                      Hotel            American Restaurant
# 37                    Gay Bar                           Café
# 38                      Hotel            American Restaurant
#
#         6th Most Common Venue       7th Most Common Venue  \
# 0                     Theater          Seafood Restaurant
# 1   Middle Eastern Restaurant                   Juice Bar
# 2              Cosmetics Shop                        Café
# 3         American Restaurant                   Gastropub
# 4         Dumpling Restaurant                 Fish Market
# 5              Breakfast Spot                 Cheese Shop
# 6             Bubble Tea Shop              Sandwich Place
# 8                      Bakery                Concert Hall
# 10                 Donut Shop                 Fish Market
# 11      Vietnamese Restaurant                 Pizza Place
# 13         Italian Restaurant                         Bar
# 14     Thrift / Vintage Store           French Restaurant
# 15         Italian Restaurant                Liquor Store
# 16        Japanese Restaurant                         Gym
# 17                Flower Shop                 Fish Market
# 20                       Food                 Flower Shop
# 23                 Donut Shop           Fish & Chips Shop
# 24               Liquor Store  Modern European Restaurant
# 25            Thai Restaurant               Grocery Store
# 26                Coffee Shop                 Pizza Place
# 27         Italian Restaurant                 Yoga Studio
# 28                Coffee Shop                         Pub
# 29                Fish Market           Fish & Chips Shop
# 30        Dumpling Restaurant               Grocery Store
# 31                Supermarket                Liquor Store
# 32                        Bar        Gym / Fitness Center
# 34           Asian Restaurant          Italian Restaurant
# 35                        Pub          Italian Restaurant
# 36              Deli / Bodega         Japanese Restaurant
# 37                        Pub                 Men's Store
# 38           Asian Restaurant          Italian Restaurant
#
#        8th Most Common Venue 9th Most Common Venue   10th Most Common Venue
# 0         Mexican Restaurant            Food Truck        French Restaurant
# 1         Italian Restaurant   Fried Chicken Joint      Distribution Center
# 2                 Restaurant               Theater            Movie Theater
# 3                      Diner        Clothing Store                   Bakery
# 4          Fish & Chips Shop  Fast Food Restaurant           Farmers Market
# 5                       Café              Beer Bar                    Hotel
# 6       Fast Food Restaurant    Italian Restaurant               Restaurant
# 8                 Steakhouse        Cosmetics Shop         Sushi Restaurant
# 10         Fish & Chips Shop        Farmers Market       Falafel Restaurant
# 11          Asian Restaurant           Yoga Studio  New American Restaurant
# 13                 Gastropub    Seafood Restaurant              Salad Place
# 14                 Pet Store    Mexican Restaurant                 Boutique
# 15         Fish & Chips Shop  Fast Food Restaurant            Movie Theater
# 16             Deli / Bodega    Seafood Restaurant       Italian Restaurant
# 17         Fish & Chips Shop  Fast Food Restaurant           Farmers Market
# 20               Fish Market     Fish & Chips Shop     Fast Food Restaurant
# 23      Fast Food Restaurant        Farmers Market                     Farm
# 24         French Restaurant           Coffee Shop   Furniture / Home Store
# 25                      Park           Pizza Place           Sandwich Place
# 26               Gas Station  Fast Food Restaurant       Seafood Restaurant
# 27                      Bank           Flower Shop       Chinese Restaurant
# 28        Falafel Restaurant            Restaurant                Gastropub
# 29      Fast Food Restaurant        Farmers Market                     Farm
# 30               Gaming Cafe                Bakery       Chinese Restaurant
# 31      Ethiopian Restaurant    Falafel Restaurant                     Farm
# 32        Italian Restaurant                Lounge                Speakeasy
# 34                       Gym            Taco Place      Japanese Restaurant
# 35                      Park            Restaurant        Convenience Store
# 36                       Bar      Asian Restaurant       Seafood Restaurant
# 37  Mediterranean Restaurant                 Hotel         Sushi Restaurant
# 38                       Gym            Taco Place      Japanese Restaurant
